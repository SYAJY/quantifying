# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Total License Count Data

# %%
df = pd.read_csv('license_counts.csv')
df.head()
# Out:
#    cc-by  cc-by-sa  cc-by-nd  cc-by-nc  cc-by-nc-sa  cc-by-nc-nd
# 0  12717      2614       552      6352        20320         4438

# %%
plt.bar(df.columns, df.iloc[0])
plt.title("Works per License within Open Education Resources")
plt.xlabel("License")
plt.ylabel("Number of Works")
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Licensed Works Data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
oer_df = pd.read_csv("oer.csv", delimiter='\t')

# %%
oer_df = oer_df.rename(columns={"Education Level": "education_level", "Subject Area": "subject_area", "Material Type": "material_type", "Media Format": "media_format", "Primary User": "primary_user", "Educational Use": "educational_use"})

# %%
oer_df['modification_date'] = oer_df['modification_date'].apply(pd.to_datetime)

# %%
# Expand columns
new_columns = {
    "education_level": [],
    "subject_area": [],
    "material_type": [],
    "media_format": [],
    "Languages": [],
    "primary_user": [],
    "educational_use": []
}
new_columns
# Out:
# {'education_level': [],
#  'subject_area': [],
#  'material_type': [],
#  'media_format': [],
#  'Languages': [],
#  'primary_user': [],
#  'educational_use': []}

# %%
def get_unique_values(column):
    lst = oer_df[column].unique()
    set_items = set()
    # Get unique values
    for item in lst:
        split = str(item).split(",")
        for value in split:
            set_items.add(value)
    # Create new columns
    for item in set_items:
        oer_df[f'{column}_{item}'] = False
        new_columns[column].append(f'{column}_{item}')
    # return set_items

for key in new_columns:
    get_unique_values(key)

new_columns
# Out:
# {'education_level': ['education_level_preschool',
#   'education_level_adult-education',
#   'education_level_graduate-professional',
#   'education_level_community-college-lower-division',
#   'education_level_upper-primary',
#   'education_level_nan',
#   'education_level_career-technical',
#   'education_level_college-upper-division',
#   'education_level_middle-school',
#   'education_level_lower-primary',
#   'education_level_high-school'],
#  'subject_area': ['subject_area_ratios-and-proportions',
#   'subject_area_finance',
#   'subject_area_life-science',
#   'subject_area_anthropology',
#   'subject_area_zoology',
#   'subject_area_environmental-science',
#   'subject_area_arts-and-humanities',
#   'subject_area_mathematics',
#   'subject_area_social-work',
#   'subject_area_maritime-science',
#   'subject_area_reading-informational-text',
#   'subject_area_visual-arts',
#   'subject_area_linguistics',
#   'subject_area_numbers-and-operations',
#   'subject_area_geology',
#   'subject_area_reading-foundation-skills',
#   'subject_area_anatomy-physiology',
#   'subject_area_communication',
#   'subject_area_atmospheric-science',
#   'subject_area_agriculture',
#   'subject_area_physical-geography',
#   'subject_area_statistics-and-probability',
#   'subject_area_political-science',
#   'subject_area_botany',
#   'subject_area_algebra',
#   'subject_area_trigonometry',
#   'subject_area_functions',
#   'subject_area_journalism',
#   'subject_area_reading-literature',
#   'subject_area_environmental-studies',
#   'subject_area_accounting',
#   'subject_area_welding',
#   'subject_area_film-and-music-production',
#   'subject_area_speaking-and-listening',
#   'subject_area_nutrition',
#   'subject_area_genetics',
#   'subject_area_performing-arts',
#   'subject_area_information-science',
#   'subject_area_language-grammar-and-vocabulary',
#   'subject_area_composition-and-rhetoric',
#   'subject_area_management',
#   'subject_area_psychology',
#   'subject_area_chemistry',
#   'subject_area_archaeology',
#   'subject_area_computer-science',
#   'subject_area_manufacturing',
#   'subject_area_applied-science',
#   'subject_area_astronomy',
#   'subject_area_automotive-technology-and-repair',
#   'subject_area_english-language-arts',
#   'subject_area_forestry-and-agriculture',
#   'subject_area_career-and-technical-education',
#   'subject_area_economics',
#   'subject_area_educational-technology',
#   'subject_area_world-history',
#   'subject_area_measurement-and-data',
#   'subject_area_engineering',
#   'subject_area_art-history',
#   'subject_area_graphic-arts',
#   'subject_area_architecture-and-design',
#   'subject_area_geometry',
#   'subject_area_early-childhood-development',
#   'subject_area_religious-studies',
#   'subject_area_education',
#   'subject_area_ecology',
#   'subject_area_cultural-geography',
#   'subject_area_culinary-arts',
#   'subject_area_higher-education',
#   'subject_area_ancient-history',
#   'subject_area_history',
#   'subject_area_calculus',
#   'subject_area_social-science',
#   'subject_area_physics',
#   'subject_area_marketing',
#   'subject_area_languages',
#   'subject_area_world-cultures',
#   'subject_area_special-education',
#   'subject_area_health-medicine-and-nursing',
#   'subject_area_business-and-communication',
#   'subject_area_ethnic-studies',
#   'subject_area_sociology',
#   'subject_area_biology',
#   'subject_area_general-law',
#   'subject_area_language-education-esl',
#   'subject_area_graphic-design',
#   'subject_area_women-s-studies',
#   'subject_area_hydrology',
#   'subject_area_criminal-justice',
#   'subject_area_literature',
#   'subject_area_u-s-history',
#   'subject_area_philosophy',
#   'subject_area_oceanography',
#   'subject_area_elementary-education',
#   'subject_area_law',
#   'subject_area_public-relations',
#   'subject_area_electronic-technology',
#   'subject_area_nan',
#   'subject_area_physical-science'],
#  'material_type': ['material_type_interactive',
#   'material_type_case-study',
#   'material_type_reading',
#   'material_type_diagram-illustration',
#   'material_type_lecture-notes',
#   'material_type_textbook',
#   'material_type_teaching-learning-strategy',
#   'material_type_lesson-plan',
#   'material_type_game',
#   'material_type_lesson',
#   'material_type_unit-of-study',
#   'material_type_homework-assignment',
#   'material_type_syllabus',
#   'material_type_assessment',
#   'material_type_student-guide',
#   'material_type_primary-source',
#   'material_type_full-course',
#   'material_type_data-set',
#   'material_type_module',
#   'material_type_lecture',
#   'material_type_simulation',
#   'material_type_activity-lab',
#   'material_type_nan'],
#  'media_format': ['media_format_ebook',
#   'media_format_audio',
#   'media_format_other',
#   'media_format_braille-brf',
#   'media_format_graphics-photos',
#   'media_format_interactive',
#   'media_format_nan',
#   'media_format_mobile',
#   'media_format_video',
#   'media_format_text-html',
#   'media_format_downloadable-docs'],
#  'Languages': ['Languages_et',
#   'Languages_uk',
#   'Languages_eu',
#   'Languages_ja',
#   'Languages_el',
#   'Languages_fo',
#   'Languages_ro',
#   'Languages_xh',
#   'Languages_bn',
#   'Languages_ko',
#   'Languages_fi',
#   'Languages_gl',
#   'Languages_th',
#   'Languages_rn',
#   'Languages_kw',
#   'Languages_mk',
#   'Languages_uz',
#   'Languages_it',
#   'Languages_yi',
#   'Languages_ur',
#   'Languages_sr',
#   'Languages_ca',
#   'Languages_zu',
#   'Languages_de',
#   'Languages_no',
#   'Languages_lo',
#   'Languages_cs',
#   'Languages_qu',
#   'Languages_bg',
#   'Languages_tg',
#   'Languages_ar',
#   'Languages_es',
#   'Languages_hu',
#   'Languages_id',
#   'Languages_sd',
#   'Languages_ht',
#   'Languages_aa',
#   'Languages_kk',
#   'Languages_ml',
#   'Languages_ka',
#   'Languages_mi',
#   'Languages_sm',
#   'Languages_sgn',
#   'Languages_te',
#   'Languages_eo',
#   'Languages_so',
#   'Languages_da',
#   'Languages_nl',
#   'Languages_yo',
#   'Languages_am',
#   'Languages_mn',
#   'Languages_ms',
#   'Languages_tr',
#   'Languages_ru',
#   'Languages_sa',
#   'Languages_bh',
#   'Languages_tn',
#   'Languages_hr',
#   'Languages_la',
#   'Languages_vi',
#   'Languages_rw',
#   'Languages_pa',
#   'Languages_lv',
#   'Languages_ab',
#   'Languages_st',
#   'Languages_sw',
#   'Languages_mr',
#   'Languages_si',
#   'Languages_lt',
#   'Languages_ss',
#   'Languages_ln',
#   'Languages_tl',
#   'Languages_cy',
#   'Languages_ba',
#   'Languages_ga',
#   'Languages_sg',
#   'Languages_fa',
#   'Languages_sk',
#   'Languages_ha',
#   'Languages_hi',
#   'Languages_km',
#   'Languages_en',
#   'Languages_ug',
#   'Languages_af',
#   'Languages_fr',
#   'Languages_he',
#   'Languages_hy',
#   'Languages_pt',
#   'Languages_sv',
#   'Languages_ia',
#   'Languages_tk',
#   'Languages_as',
#   'Languages_sq',
#   'Languages_sl',
#   'Languages_ta',
#   'Languages_nan',
#   'Languages_zh',
#   'Languages_pl'],
#  'primary_user': ['primary_user_librarian',
#   'primary_user_teacher',
#   'primary_user_other',
#   'primary_user_student',
#   'primary_user_administrator',
#   'primary_user_nan',
#   'primary_user_parent'],
#  'educational_use': ['educational_use_informal-education',
#   'educational_use_curriculum-instruction',
#   'educational_use_assessment',
#   'educational_use_other',
#   'educational_use_nan',
#   'educational_use_professional-development']}

# %%
def expand_columns(row):
    for key in new_columns:
        split = str(row[key]).split(",")
        for item in split:
            row[f'{key}_{item}'] = True
    return row

# %%
oer_df = oer_df.apply(expand_columns, axis=1)

# %%
oer_df.head()
# Out:
#       id license modification_date            education_level  subject_area  \
# 0  86509   cc-by        2023-02-01  middle-school,high-school   u-s-history
# 1  88278   cc-by        2021-11-23              lower-primary   mathematics
# 2  73381   cc-by        2020-10-14              lower-primary   mathematics
# 3   6153   cc-by        2019-08-08  upper-primary,high-school   mathematics
# 4   8397   cc-by        2016-01-28                high-school  life-science
#
#                                        material_type  \
# 0                                        lesson-plan
# 1                                       activity-lab
# 2                                        interactive
# 3  activity-lab,lesson-plan,teaching-learning-str...
# 4                                        full-course
#
#                   media_format Languages     primary_user  \
# 0      downloadable-docs,video        en          teacher
# 1                          NaN        en              NaN
# 2                          NaN        en              NaN
# 3                    text-html        en          teacher
# 4  downloadable-docs,text-html        en  student,teacher
#
#             educational_use  ...  primary_user_student  \
# 0    curriculum-instruction  ...                 False
# 1                       NaN  ...                 False
# 2                       NaN  ...                 False
# 3  professional-development  ...                 False
# 4    curriculum-instruction  ...                  True
#
#    primary_user_administrator  primary_user_nan  primary_user_parent  \
# 0                       False             False                False
# 1                       False              True                False
# 2                       False              True                False
# 3                       False             False                False
# 4                       False             False                False
#
#    educational_use_informal-education  educational_use_curriculum-instruction  \
# 0                               False                                    True
# 1                               False                                   False
# 2                               False                                   False
# 3                               False                                   False
# 4                               False                                    True
#
#    educational_use_assessment  educational_use_other  educational_use_nan  \
# 0                       False                  False                False
# 1                       False                  False                 True
# 2                       False                  False                 True
# 3                       False                  False                False
# 4                       False                  False                False
#
#    educational_use_professional-development
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
# [5 rows x 264 columns]

# %%
#Create pie chart visualization - showing the percentage of items that are attached to each CC license type
sns.set_theme(font="arial", font_scale=1.1)
plt.pie(oer_df['license'].value_counts(), labels = oer_df['license'].unique(), 
        colors = sns.color_palette('pastel')[0:6], autopct='%.0f%%')
plt.title('Percentage of Items per License Type')
plt.show()

# %%
license = oer_df.groupby('license')
unique_media_type = license.apply(lambda x: x['media_format'].unique())
oer_df1 = oer_df.dropna(subset=['media_format'])
oer_df1['media_format_explode'] = oer_df1['media_format'].apply(lambda x: x.split(','))
oer_df1 = oer_df1.explode('media_format_explode')

license = oer_df1.groupby('license')
unique_media_type = license.apply(lambda x: x['media_format_explode'].unique())
# Out:
# ['downloadable-docs' 'video' 'text-html' 'graphics-photos' 'interactive'
#  'audio' 'ebook' 'other' 'mobile' 'braille-brf']

# %%
plt.
